# %%
#trabajo 1

import random
def separar_pares_impares(numeros)
par[]
impar[]
for numero in numeros:
    if numero %2 == 0:
        pares.append(numero)
    else:
        impares.append(numero)

    return sorted(pares), sorted(impares)  

if __namme__ == "__main__":
    lista=[random.randint(0,9) for _ in range(10)]
    pares, impares = separar_pares_impares
    
    print ("lista de numeros", lista)
    print ("numeros pares ordenados", pares)
    print ("numeros impares ordenaddos", impares)

# %%
#trabajo 2

def contar_letras(palabras):
    contador = {}
    
    for letra in palabras:
    if letra in contador:
        contador[letra] +=1
    else:
        contador[letra] = 1
        
        return contador
    
    if __name__ == "__main__":
        palabras = int(input("ingresa una palabra"))
        resultado = contar_letras(palabras)
        
        print("\n conteo de letras:")
        for letra, cantidad in resultado.items():
            print(f"'{letra}': {cantidad}")

# %%
#trabajo 3

def numero_a_palabras(numero):
    """
    Recibe un número entero y devuelve una cadena con los nombres
    de sus dígitos separados por guiones.
    """
    nombres_digitos = {
        '0': 'cero',
        '1': 'uno',
        '2': 'dos',
        '3': 'tres',
        '4': 'cuatro',
        '5': 'cinco',
        '6': 'seis',
        '7': 'siete',
        '8': 'ocho',
        '9': 'nueve'
    }

    numero_str = str(abs(numero))  # Convertir a string y manejar negativos
    palabras = [nombres_digitos[d] for d in numero_str]
    resultado = '-'.join(palabras)

    # Agregar "menos" si el número era negativo
    if numero < 0:
        resultado = "menos-" + resultado

    return resultado

def mostrar_digitos_disponibles():
    """
    Imprime los dígitos disponibles y sus nombres.
    """
    nombres_digitos = {
        '0': 'cero',
        '1': 'uno',
        '2': 'dos',
        '3': 'tres',
        '4': 'cuatro',
        '5': 'cinco',
        '6': 'seis',
        '7': 'siete',
        '8': 'ocho',
        '9': 'nueve'
    }

    print("Dígitos disponibles:")
    for d, nombre in nombres_digitos.items():
        print(f"{d} - {nombre}")

if __name__ == "__main__":
    mostrar_digitos_disponibles()
    numero = int(input("Ingresa un número: "))
    resultado = numero_a_palabras(numero)
    print("Resultado:", resultado)
